# %% [markdown]
# ##### Importieren der notwendigen Bibliotheken:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ##### Lesen der Verkaufsdaten

# %%
sales_df = pd.read_csv("sales_clean.csv")
sales_df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo  SchoolHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1              1
# 1      2          5  2015-07-31   6064        625     1      1              1
# 2      3          5  2015-07-31   8314        821     1      1              1
# 3      4          5  2015-07-31  13995       1498     1      1              1
# 4      5          5  2015-07-31   4822        559     1      1              1
#
#    PublicHoliday  Easter  Christmas
# 0              0       0          0
# 1              0       0          0
# 2              0       0          0
# 3              0       0          0
# 4              0       0          0

# %% [markdown]
# ##### Erstellung neuer Metriken

# %% [markdown]
# Wir werden die Daten von 942 aggregieren, um individuelle Leistungsberichte für jede der Filialen zu erstellen. Die Spalten Date und DayOfWeek werden wir für diese Anlyse nicht mehr brauchen.

# %%
sales_df.drop(['Date', 'DayOfWeek'], axis=1, inplace=True)

# %% [markdown]
# Und nun gruppieren wir die Daten auf `Store` Ebene

# %%
global_sales_df = sales_df.groupby('Store').sum()
global_sales_df.head()
# Out:
#          Sales  Customers  Open  Promo  SchoolHoliday  PublicHoliday  Easter  \
# Store
# 1      3716854     440523   781    360            193             17       6
# 2      3883858     457855   784    360            167             15       6
# 3      5408261     584310   779    360            170             19       6
# 4      7556507    1036254   784    360            173             14       6
# 5      3642818     418588   779    360            172             21       6
#
#        Christmas
# Store
# 1              4
# 2              4
# 3              4
# 4              4
# 5              4

# %% [markdown]
# Wir erstellen drei neue Variablen: `SalesPerDay`, `CustomersDay` und `SalesPerCustomer`.

# %%
global_sales_df['SalesPerDay'] = global_sales_df['Sales'] / global_sales_df['Open']
global_sales_df['CustomersPerDay'] = global_sales_df['Customers'] / global_sales_df['Open']
global_sales_df['SalesPerCustomer'] = global_sales_df['Sales'] / global_sales_df['Customers']

global_sales_df.head()
# Out:
#          Sales  Customers  Open  Promo  SchoolHoliday  PublicHoliday  Easter  \
# Store
# 1      3716854     440523   781    360            193             17       6
# 2      3883858     457855   784    360            167             15       6
# 3      5408261     584310   779    360            170             19       6
# 4      7556507    1036254   784    360            173             14       6
# 5      3642818     418588   779    360            172             21       6
#
#        Christmas  SalesPerDay  CustomersPerDay  SalesPerCustomer
# Store
# 1              4  4759.096031       564.049936          8.437366
# 2              4  4953.900510       583.998724          8.482725
# 3              4  6942.568678       750.077022          9.255808
# 4              4  9638.401786      1321.752551          7.292138
# 5              4  4676.274711       537.340180          8.702634

# %% [markdown]
# ##### Verknüpfung mit den Daten der Filialen:

# %%
stores_df = pd.read_csv("stores_clean.csv")
sales_stores_df = pd.merge(stores_df, global_sales_df, how = 'inner', on = 'Store')
sales_stores_df.set_index('Store', inplace=True)
sales_stores_df.head()
# Out:
#       StoreType Assortment  CompetitionDistance  Promo2    PromoInterval  \
# Store
# 1             c          a               1270.0       0              NaN
# 2             a          a                570.0       1  Jan,Apr,Jul,Oct
# 3             a          a              14130.0       1  Jan,Apr,Jul,Oct
# 4             c          c                620.0       0              NaN
# 5             a          a              29910.0       0              NaN
#
#       CompetitionOpenSince Promo2Since    Sales  Customers  Open  Promo  \
# Store
# 1               2008-09-01         NaN  3716854     440523   781    360
# 2               2007-11-01  2010-03-29  3883858     457855   784    360
# 3               2006-12-01  2011-04-04  5408261     584310   779    360
# 4               2009-09-01         NaN  7556507    1036254   784    360
# 5               2015-04-01         NaN  3642818     418588   779    360
#
#        SchoolHoliday  PublicHoliday  Easter  Christmas  SalesPerDay  \
# Store
# 1                193             17       6          4  4759.096031
# 2                167             15       6          4  4953.900510
# 3                170             19       6          4  6942.568678
# 4                173             14       6          4  9638.401786
# 5                172             21       6          4  4676.274711
#
#        CustomersPerDay  SalesPerCustomer
# Store
# 1           564.049936          8.437366
# 2           583.998724          8.482725
# 3           750.077022          9.255808
# 4          1321.752551          7.292138
# 5           537.340180          8.702634

# %% [markdown]
# Betrachten wir die deskriptiven Statistiken für die Variablen, die direkt mit dem Gesamtumsatz zusammenhängen.

# %%
sales_vars = ['Sales', 'SalesPerDay', 'CustomersPerDay', 'SalesPerCustomer']
sales_stores_df[sales_vars].describe().apply(lambda x: x.apply('{0:.5f}'.format))
# Out:
#                 Sales  SalesPerDay CustomersPerDay SalesPerCustomer
# count      1115.00000   1115.00000      1115.00000       1115.00000
# mean    5267426.56771   6934.20845       754.51016          9.64376
# std     1951304.48397   2383.91105       353.34441          1.98686
# min     2114322.00000   2703.73657       240.18310          3.51370
# 25%     3949377.00000   5322.29997       541.46869          8.13186
# 50%     4990259.00000   6589.94847       678.66752          9.46406
# 75%     6084147.50000   7964.20064       866.20330         10.98117
# max    19516842.00000  21757.48342      3403.45860         16.16264

# %% [markdown]
# In der ersten Analyse hatten wir schon festgestellt, dass einige Filialen oft weit überdurchschnittliche Gewinne erzielen.
# Dies sind die Filialen, deren Gesamtumsatz mehr als 3 Standardabweichungen über dem Durchschnitt liegt.

# %%
sales_mean = sales_stores_df['Sales'].mean()
sales_std = sales_stores_df['Sales'].std()
high_sales = sales_mean + 3*sales_std

outlier_stores = sales_stores_df[sales_stores_df['Sales'] > high_sales].sort_values(by='Sales', ascending=False).index
sales_stores_df.iloc[outlier_stores]
# Out:
#       StoreType Assortment  CompetitionDistance  Promo2     PromoInterval  \
# Store
# 263           a          c               1140.0       1   Jan,Apr,Jul,Oct
# 818           d          a                490.0       1  Mar,Jun,Sept,Dec
# 563           a          a                700.0       1   Jan,Apr,Jul,Oct
# 1115          d          c               5350.0       1  Mar,Jun,Sept,Dec
# 252           d          c              22330.0       1   Feb,May,Aug,Nov
# 514           c          c               1200.0       1   Jan,Apr,Jul,Oct
# 789           a          c               9770.0       0               NaN
# 734           a          a                220.0       1  Mar,Jun,Sept,Dec
# 384           a          c                130.0       1   Jan,Apr,Jul,Oct
# 757           a          c               3450.0       0               NaN
# 336           a          a                190.0       0               NaN
# 699           a          a                180.0       1   Jan,Apr,Jul,Oct
# 524           a          c              40860.0       0               NaN
# 596           c          a                290.0       0               NaN
# 587           d          c                330.0       1   Jan,Apr,Jul,Oct
# 321           c          c               8140.0       1  Mar,Jun,Sept,Dec
# 843           c          a                 60.0       0               NaN
# 381           a          a               1800.0       1   Feb,May,Aug,Nov
#
#       CompetitionOpenSince Promo2Since     Sales  Customers  Open  Promo  \
# Store
# 263             2013-05-01  2014-10-06   2306075     221342   622    286
# 818             2010-02-01  2010-08-30   4772357     496141   781    360
# 563             2015-03-01  2014-03-10   4278470     545236   776    360
# 1115            2010-02-01  2012-05-28   4922229     337884   781    360
# 252             2010-02-01  2010-02-01   8269484     630702   779    360
# 514             2012-07-01  2012-07-02   3580238     375667   622    286
# 789             2003-07-01         NaN   2626269     364576   777    360
# 734             2010-02-01  2013-09-09   4658828     440954   779    360
# 384             2010-02-01  2011-04-04   6937572     781105   782    360
# 757             2010-02-01         NaN   4832775     416360   777    360
# 336             2014-07-01         NaN  10850316    1529043   780    360
# 699             2010-02-01  2013-02-04   6373219     749312   766    360
# 524             2013-09-01         NaN   6793232     721100   881    360
# 596             2006-09-01         NaN   3532562     547535   784    360
# 587             2006-09-01  2011-04-04   6020227     427184   623    286
# 321             2013-11-01  2014-03-10   4647488     456662   780    360
# 843             2006-04-01         NaN   7423466     875136   784    360
# 381             2006-11-01  2013-02-04   7021213     752849   780    360
#
#        SchoolHoliday  PublicHoliday  Easter  Christmas   SalesPerDay  \
# Store
# 263              124             21       6          2   3707.516077
# 818              193             17       6          4   6110.572343
# 563              170             19       6          4   5513.492268
# 1115             193             17       6          4   6302.469910
# 252              170             19       6          4  10615.512195
# 514              124             21       6          2   5756.009646
# 789              155             22       6          4   3380.011583
# 734              170             19       6          4   5980.523748
# 384              167             15       6          4   8871.575448
# 757              155             22       6          4   6219.787645
# 336              193             17       6          4  13910.661538
# 699              193             17       6          4   8320.129243
# 524              159             14       6          4   7710.819523
# 596              173             14       6          4   4505.818878
# 587              124             21       6          2   9663.285714
# 321              172             21       6          4   5958.317949
# 843              173             14       6          4   9468.706633
# 381              168             19       6          4   9001.555128
#
#        CustomersPerDay  SalesPerCustomer
# Store
# 263         355.855305         10.418606
# 818         635.263764          9.618953
# 563         702.623711          7.847006
# 1115        432.629962         14.567807
# 252         809.630295         13.111555
# 514         603.966238          9.530350
# 789         469.209781          7.203626
# 734         566.051348         10.565338
# 384         998.855499          8.881741
# 757         535.855856         11.607203
# 336        1960.311538          7.096148
# 699         978.214099          8.505428
# 524         818.501703          9.420652
# 596         698.386480          6.451756
# 587         685.688604         14.092819
# 321         585.464103         10.177085
# 843        1116.244898          8.482643
# 381         965.191026          9.326190
